# %%
import pandas as pd

# %%
dbz = pd.DataFrame(
    {
        'nombre':['Goku','Vegeta'],
        'nombre_saiyayin':['Kakaroto','Vegeta'],
        'edad':[33,30]
    }
)

dbz
# Out:
#    nombre nombre_saiyayin  edad
# 0    Goku        Kakaroto    33
# 1  Vegeta          Vegeta    30

# %%
dbz1 = pd.DataFrame(
    [
        ['Goku','Kakaroto',33],
        ['Vegeta','Vegeta',39]
    ], columns = ['Nombre','Nombre_Saiyayin','Edad']
)

dbz1
# Out:
#    Nombre Nombre_Saiyayin  Edad
# 0    Goku        Kakaroto    33
# 1  Vegeta          Vegeta    39

# %%
type(dbz)
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.read_csv('../Dataset/primary_results.csv')
df.tail(15)
# Out:
#          state state_abbreviation             county        fips       party  \
# 24596  Wyoming                 WY  Sheridan-Big Horn  95600031.0  Republican
# 24597  Wyoming                 WY  Sheridan-Big Horn  95600031.0  Republican
# 24598  Wyoming                 WY  Sheridan-Big Horn  95600031.0  Republican
# 24599  Wyoming                 WY  Sweetwater-Carbon  95600026.0  Republican
# 24600  Wyoming                 WY  Sweetwater-Carbon  95600026.0  Republican
# 24601  Wyoming                 WY  Sweetwater-Carbon  95600026.0  Republican
# 24602  Wyoming                 WY  Sweetwater-Carbon  95600026.0  Republican
# 24603  Wyoming                 WY     Teton-Sublette  95600028.0  Republican
# 24604  Wyoming                 WY     Teton-Sublette  95600028.0  Republican
# 24605  Wyoming                 WY     Teton-Sublette  95600028.0  Republican
# 24606  Wyoming                 WY     Teton-Sublette  95600028.0  Republican
# ...

# %%
df.dtypes
# Out:
# state                  object
# state_abbreviation     object
# county                 object
# fips                  float64
# party                  object
# candidate              object
# votes                   int64
# fraction_votes        float64
# dtype: object

# %%
df.describe()
# Out:
#                fips          votes  fraction_votes
# count  2.451100e+04   24611.000000    24611.000000
# mean   2.667152e+07    2306.252773        0.304524
# std    4.200978e+07    9861.183572        0.231401
# min    1.001000e+03       0.000000        0.000000
# 25%    2.109100e+04      68.000000        0.094000
# 50%    4.208100e+04     358.000000        0.273000
# 75%    9.090012e+07    1375.000000        0.479000
# max    9.560004e+07  590502.000000        1.000000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=24611, step=1)

# %%
df.loc[0]
# Out:
# state                        Alabama
# state_abbreviation                AL
# county                       Autauga
# fips                            1001
# party                       Democrat
# candidate             Bernie Sanders
# votes                            544
# fraction_votes                 0.182
# Name: 0, dtype: object

# %%
df2 = df.set_index('county')
df2.head(10)
# Out:
#            state state_abbreviation    fips     party        candidate  votes  \
# county
# Autauga  Alabama                 AL  1001.0  Democrat   Bernie Sanders    544
# Autauga  Alabama                 AL  1001.0  Democrat  Hillary Clinton   2387
# Baldwin  Alabama                 AL  1003.0  Democrat   Bernie Sanders   2694
# Baldwin  Alabama                 AL  1003.0  Democrat  Hillary Clinton   5290
# Barbour  Alabama                 AL  1005.0  Democrat   Bernie Sanders    222
# Barbour  Alabama                 AL  1005.0  Democrat  Hillary Clinton   2567
# Bibb     Alabama                 AL  1007.0  Democrat   Bernie Sanders    246
# Bibb     Alabama                 AL  1007.0  Democrat  Hillary Clinton    942
# Blount   Alabama                 AL  1009.0  Democrat   Bernie Sanders    395
# Blount   Alabama                 AL  1009.0  Democrat  Hillary Clinton    564
#
#          fraction_votes
# county
# Autauga           0.182
# Autauga           0.800
# ...

# %%
df['state'].head(10)
# Out:
# 0    Alabama
# 1    Alabama
# 2    Alabama
# 3    Alabama
# 4    Alabama
# 5    Alabama
# 6    Alabama
# 7    Alabama
# 8    Alabama
# 9    Alabama
# Name: state, dtype: object

# %%
df[(df.county == 'Manhattan') & (df.party == 'Republican')]
# Out:
#           state state_abbreviation     county     fips       party  \
# 15162  New York                 NY  Manhattan  36061.0  Republican
# 15163  New York                 NY  Manhattan  36061.0  Republican
# 15164  New York                 NY  Manhattan  36061.0  Republican
#
#           candidate  votes  fraction_votes
# 15162  Donald Trump  10393           0.418
# 15163   John Kasich  11251           0.452
# 15164      Ted Cruz   3243           0.130

# %%
df.query("county == 'Manhattan' and party=='Republican' ")
# Out:
#           state state_abbreviation     county     fips       party  \
# 15162  New York                 NY  Manhattan  36061.0  Republican
# 15163  New York                 NY  Manhattan  36061.0  Republican
# 15164  New York                 NY  Manhattan  36061.0  Republican
#
#           candidate  votes  fraction_votes
# 15162  Donald Trump  10393           0.418
# 15163   John Kasich  11251           0.452
# 15164      Ted Cruz   3243           0.130

# %%
df.sort_values(by = 'votes', ascending=False).head()
# Out:
#            state state_abbreviation        county        fips     party  \
# 1386  California                 CA   Los Angeles      6037.0  Democrat
# 1385  California                 CA   Los Angeles      6037.0  Democrat
# 4451    Illinois                 IL       Chicago  91700103.0  Democrat
# 4450    Illinois                 IL       Chicago  91700103.0  Democrat
# 4463    Illinois                 IL  Cook Suburbs  91700104.0  Democrat
#
#             candidate   votes  fraction_votes
# 1386  Hillary Clinton  590502           0.570
# 1385   Bernie Sanders  434656           0.420
# 4451  Hillary Clinton  366954           0.536
# 4450   Bernie Sanders  311225           0.454
# 4463  Hillary Clinton  249217           0.536

# %%
df.sort_index().head()
# Out:
#      state state_abbreviation   county    fips     party        candidate  \
# 0  Alabama                 AL  Autauga  1001.0  Democrat   Bernie Sanders
# 1  Alabama                 AL  Autauga  1001.0  Democrat  Hillary Clinton
# 2  Alabama                 AL  Baldwin  1003.0  Democrat   Bernie Sanders
# 3  Alabama                 AL  Baldwin  1003.0  Democrat  Hillary Clinton
# 4  Alabama                 AL  Barbour  1005.0  Democrat   Bernie Sanders
#
#    votes  fraction_votes
# 0    544           0.182
# 1   2387           0.800
# 2   2694           0.329
# 3   5290           0.647
# 4    222           0.078

# %%
df2 = pd.read_csv('../Dataset/PovertyEstimates.csv')
df2.head()
# Out:
#    FIPStxt  PCTPOVALL_2015
# 0        0            14.7
# 1     1000            18.5
# 2     1001            12.7
# 3     1003            12.9
# 4     1005            32.0

# %%
df.groupby(['state','party'])['votes'].sum()
# Out:
# state           party
# Alabama         Democrat       386327
#                 Republican     837632
# Alaska          Democrat          539
#                 Republican      21930
# Arizona         Democrat       399097
#                 Republican     435103
# Arkansas        Democrat       209448
#                 Republican     396523
# California      Democrat      3442623
#                 Republican    1495574
# Colorado        Democrat       121184
# Connecticut     Democrat       322485
#                 Republican     208817
# Delaware        Democrat        92609
#                 Republican      67807
# Florida         Democrat      1664003
#                 Republican    2276926
# Georgia         Democrat       757340
#                 Republican    1275601
# Hawaii          Democrat        33658
#                 Republican      13228
# Idaho           Democrat        23705
#                 Republican     215284
# Illinois        Democrat      1987834
# ...

# %%
df['letra_inicial']=df.state_abbreviation.apply(lambda s: s[0])

# %%
df.head()
# Out:
#      state state_abbreviation   county    fips     party        candidate  \
# 0  Alabama                 AL  Autauga  1001.0  Democrat   Bernie Sanders
# 1  Alabama                 AL  Autauga  1001.0  Democrat  Hillary Clinton
# 2  Alabama                 AL  Baldwin  1003.0  Democrat   Bernie Sanders
# 3  Alabama                 AL  Baldwin  1003.0  Democrat  Hillary Clinton
# 4  Alabama                 AL  Barbour  1005.0  Democrat   Bernie Sanders
#
#    votes  fraction_votes letra_inicial
# 0    544           0.182             A
# 1   2387           0.800             A
# 2   2694           0.329             A
# 3   5290           0.647             A
# 4    222           0.078             A

# %%
df_merge = df.merge(df2, left_on = 'fips', right_on = 'FIPStxt')
df_merge.head()
# Out:
#      state state_abbreviation   county    fips       party        candidate  \
# 0  Alabama                 AL  Autauga  1001.0    Democrat   Bernie Sanders
# 1  Alabama                 AL  Autauga  1001.0    Democrat  Hillary Clinton
# 2  Alabama                 AL  Autauga  1001.0  Republican       Ben Carson
# 3  Alabama                 AL  Autauga  1001.0  Republican     Donald Trump
# 4  Alabama                 AL  Autauga  1001.0  Republican      John Kasich
#
#    votes  fraction_votes letra_inicial  FIPStxt  PCTPOVALL_2015
# 0    544           0.182             A     1001            12.7
# 1   2387           0.800             A     1001            12.7
# 2   1764           0.146             A     1001            12.7
# 3   5387           0.445             A     1001            12.7
# 4    421           0.035             A     1001            12.7

# %%
df_merge.groupby(['county','party']).agg({
        'fraction_votes': 'mean',
        'PCTPOVALL_2015': 'min'
    }).head()
# Out:
#                       fraction_votes  PCTPOVALL_2015
# county    party
# Abbeville Democrat          0.494000            19.1
#           Republican        0.166667            19.1
# Acadia    Democrat          0.425500            23.7
#           Republican        0.241750            23.7
# Accomack  Democrat          0.497000            20.4
